# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("MissingMigrantsGlobal.csv", encoding= "latin", sep ="\t")

# %%
df.head(4)
# Out:
#    Web ID Region of Incident   Reported Date  Reported Year Reported Month  \
# 0   51591      Mediterranean  March 28, 2019           2019            Mar
# 1   51588      Mediterranean  March 26, 2019           2019            Mar
# 2   51589      Mediterranean  March 26, 2019           2019            Mar
# 3   51590      Mediterranean  March 26, 2019           2019            Mar
#
#    Number Dead  Minimum Estimated Number of Missing  Total Dead and Missing  \
# 0          NaN                                  2.0                       2
# 1          4.0                                  NaN                       4
# 2          1.0                                  NaN                       1
# 3          1.0                                  NaN                       1
#
#    Number of Survivors  Number of Females  Number of Males  \
# 0                 36.0                NaN              2.0
# 1                 11.0                3.0              NaN
# ...

# %%
df.columns
# Out:
# Index(['Web ID', 'Region of Incident', 'Reported Date', 'Reported Year',
#        'Reported Month', 'Number Dead', 'Minimum Estimated Number of Missing',
#        'Total Dead and Missing', 'Number of Survivors', 'Number of Females',
#        'Number of Males', 'Number of Children', 'Cause of Death',
#        'Location Description', 'Information Source', 'Location Coordinates',
#        'Migration Route', 'URL', 'UNSD Geographical Grouping',
#        'Source Quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5333 entries, 0 to 5332
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Web ID                               5333 non-null   int64
#  1   Region of Incident                   5333 non-null   object
#  2   Reported Date                        5333 non-null   object
#  3   Reported Year                        5333 non-null   int64
#  4   Reported Month                       5333 non-null   object
#  5   Number Dead                          5142 non-null   float64
#  6   Minimum Estimated Number of Missing  503 non-null    float64
#  7   Total Dead and Missing               5333 non-null   int64
#  8   Number of Survivors                  749 non-null    float64
#  9   Number of Females                    897 non-null    float64
#  10  Number of Males                      2813 non-null   float64
# ...

# %%
df.shape
# Out:
# (5333, 20)

# %%
df.describe()
# Out:
#              Web ID  Reported Year  Number Dead  \
# count   5333.000000    5333.000000  5142.000000
# mean   43247.885805    2016.656104     3.287631
# std     5186.837212       1.237033    13.593407
# min    30158.000000    2014.000000     0.000000
# 25%    40876.000000    2016.000000     1.000000
# 50%    43504.000000    2017.000000     1.000000
# 75%    45747.000000    2018.000000     2.000000
# max    51592.000000    2019.000000   750.000000
#
#        Minimum Estimated Number of Missing  Total Dead and Missing  \
# count                           503.000000             5333.000000
# mean                             29.119284                5.916370
# std                              67.913216               28.051811
# min                               0.000000                0.000000
# 25%                               2.000000                1.000000
# 50%                               7.000000                1.000000
# ...

# %%
df.isna().sum()
# Out:
# Web ID                                    0
# Region of Incident                        0
# Reported Date                             0
# Reported Year                             0
# Reported Month                            0
# Number Dead                             191
# Minimum Estimated Number of Missing    4830
# Total Dead and Missing                    0
# Number of Survivors                    4584
# Number of Females                      4436
# Number of Males                        2520
# Number of Children                     4689
# Cause of Death                            0
# Location Description                     10
# Information Source                        2
# Location Coordinates                      1
# Migration Route                        2673
# URL                                    2141
# UNSD Geographical Grouping               11
# Source Quality                            0
# dtype: int64

# %%
#What are the Top 10 Region of Incidents with higher incidents?
df["Region of Incident"].value_counts()[:10]
# Out:
# US-Mexico Border      1337
# North Africa          1239
# Mediterranean          984
# Sub-Saharan Africa     475
# Central America        309
# Europe                 249
# Horn of Africa         235
# Middle East            164
# South Asia             151
# Southeast Asia          96
# Name: Region of Incident, dtype: int64

# %%
#What is the Percentage of missing Females, Males and Children in top 10 regions of incidents?
(df.groupby("Region of Incident")["Number of Females"].sum() / df["Number of Females"].sum())*100
# Out:
# Region of Incident
# Caribbean              2.105263
# Central America        2.160665
# Central Asia           0.000000
# East Asia              0.055402
# Europe                 1.939058
# Horn of Africa         3.878116
# Mediterranean         44.930748
# Middle East            3.324100
# North Africa          14.681440
# North America          0.055402
# South America          0.720222
# South Asia             0.997230
# Southeast Asia         8.310249
# Sub-Saharan Africa    11.468144
# US-Mexico Border       5.373961
# Name: Number of Females, dtype: float64

# %%
(df.groupby("Region of Incident")["Number of Males"].sum() / df["Number of Males"].sum())*100
# Out:
# Region of Incident
# Caribbean              1.504042
# Central America        6.016168
# Central Asia           0.000000
# East Asia              0.056402
# Europe                 5.170145
# Horn of Africa         4.436924
# Mediterranean         35.683399
# Middle East            2.669675
# North Africa          11.223914
# North America          0.000000
# South America          0.394811
# South Asia             3.384095
# Southeast Asia         2.481669
# Sub-Saharan Africa     8.385035
# US-Mexico Border      18.593721
# Name: Number of Males, dtype: float64

# %%
(df.groupby("Region of Incident")["Number of Children"].sum() / df["Number of Children"].sum())*100
# Out:
# Region of Incident
# Caribbean              0.313480
# Central America        3.009404
# Central Asia           0.000000
# East Asia              0.000000
# Europe                 2.445141
# Horn of Africa         2.758621
# Mediterranean         42.006270
# Middle East            4.576803
# North Africa           9.028213
# North America          0.000000
# South America          1.065831
# South Asia             1.128527
# Southeast Asia        22.758621
# Sub-Saharan Africa     9.278997
# US-Mexico Border       1.630094
# Name: Number of Children, dtype: float64

# %% [markdown]
# ##### 3.	List most common Information Source according to region of incident wise

# %%
s = df.groupby("Region of Incident")["Information Source"].value_counts()

# %%
s["Caribbean"]
# Out:
# Information Source
# Dominican Today                                                              3
# El Nuevo Herald                                                              3
# Listin Diario                                                                2
# US Coast Guard                                                               2
# 14ymedio                                                                     1
# 7 días                                                                       1
# AP                                                                           1
# Antigua Observer                                                             1
# Associated Press                                                             1
# Avance 24 en Linea                                                           1
# CDN, Hoy Digital                                                             1
# Caribbean News Now                                                           1
# ...

# %%
s.loc["Caribbean"]
# Out:
# Information Source
# Dominican Today                                                              3
# El Nuevo Herald                                                              3
# Listin Diario                                                                2
# US Coast Guard                                                               2
# 14ymedio                                                                     1
# 7 días                                                                       1
# AP                                                                           1
# Antigua Observer                                                             1
# Associated Press                                                             1
# Avance 24 en Linea                                                           1
# CDN, Hoy Digital                                                             1
# Caribbean News Now                                                           1
# ...

# %%
for i in df["Region of Incident"].unique():
    print(i.upper().center(80))
    print()
    print(s.loc[i][:5])
    print("_"*80)
# Out:
#                                  MEDITERRANEAN
#
# Information Source
# IOM Libya               102
# IOM Italy                90
# UNHCR                    42
# Hellenic Coast Guard     24
# Hurriyet Daily News      22
# Name: Information Source, dtype: int64
# ________________________________________________________________________________
#                                 CENTRAL AMERICA
#
# Information Source
# Debate         6
# El Heraldo     4
# La 72          4
# La Journada    4
# Milenio        4
# Name: Information Source, dtype: int64
# ________________________________________________________________________________
#                                 US-MEXICO BORDER
#
# Information Source
# Pima County Office of the Medical Examiner    681
# South Texas Human Rights Center                46
# US Border Patrol                               31
# Hidalgo County Sheriff's Office                29
# Hoy Tamaulipas                                 23
# ...

# %% [markdown]
# ##### 4. What are the most common causes of death in every region?

# %%
f = df.groupby("Region of Incident")["Cause of Death"].value_counts()

# %%
f
# Out:
# Region of Incident  Cause of Death
# Caribbean           Drowning                                    25
#                     Presumed drowning                           17
#                     Unknown                                      7
#                     Shot                                         2
#                     Vehicle Accident                             2
#                                                                 ..
# US-Mexico Border    Hypoglycemia                                 1
#                     Pneumonia                                    1
#                     Train Accident                               1
#                     Unknown (mummified and skeletal remains)     1
#                     Unknown (violence)                           1
# Name: Cause of Death, Length: 454, dtype: int64

# %%
for i in df["Region of Incident"].unique():
    print(i.upper().center(80))
    print()
    print(f[i][:5])
    print("_"*80)
# Out:
#                                  MEDITERRANEAN
#
# Cause of Death
# Drowning                     535
# Presumed drowning            227
# Unknown                      138
# Hypothermia                   12
# Unknown (found on dinghy)      9
# Name: Cause of Death, dtype: int64
# ________________________________________________________________________________
#                                 CENTRAL AMERICA
#
# Cause of Death
# Fall from train     63
# Hit by train        38
# Vehicle Accident    36
# Train Accident      26
# Shot                21
# Name: Cause of Death, dtype: int64
# ________________________________________________________________________________
#                                 US-MEXICO BORDER
#
# Cause of Death
# Unknown (skeletal remains)    468
# Drowning                      261
# Unknown                       256
# Hyperthermia                   54
# Presumed drowning              49
# Name: Cause of Death, dtype: int64
# ...

# %%
for i in df["Region of Incident"].unique():
    print(i.upper().center(80))
    print()
    print(f.loc[i][:5])
    print("_"*80)
# Out:
#                                  MEDITERRANEAN
#
# Cause of Death
# Drowning                     535
# Presumed drowning            227
# Unknown                      138
# Hypothermia                   12
# Unknown (found on dinghy)      9
# Name: Cause of Death, dtype: int64
# ________________________________________________________________________________
#                                 CENTRAL AMERICA
#
# Cause of Death
# Fall from train     63
# Hit by train        38
# Vehicle Accident    36
# Train Accident      26
# Shot                21
# Name: Cause of Death, dtype: int64
# ________________________________________________________________________________
#                                 US-MEXICO BORDER
#
# Cause of Death
# Unknown (skeletal remains)    468
# Drowning                      261
# Unknown                       256
# Hyperthermia                   54
# Presumed drowning              49
# Name: Cause of Death, dtype: int64
# ...

# %% [markdown]
# ##### 5. List number of cases reported month wise in year 2019 ?

# %%
df.head(3)
# Out:
#    Web ID Region of Incident   Reported Date  Reported Year Reported Month  \
# 0   51591      Mediterranean  March 28, 2019           2019            Mar
# 1   51588      Mediterranean  March 26, 2019           2019            Mar
# 2   51589      Mediterranean  March 26, 2019           2019            Mar
#
#    Number Dead  Minimum Estimated Number of Missing  Total Dead and Missing  \
# 0          NaN                                  2.0                       2
# 1          4.0                                  NaN                       4
# 2          1.0                                  NaN                       1
#
#    Number of Survivors  Number of Females  Number of Males  \
# 0                 36.0                NaN              2.0
# 1                 11.0                3.0              NaN
# 2                  NaN                NaN              NaN
#
#    Number of Children     Cause of Death  \
# 0                 NaN  Presumed drowning
# ...

# %%
df[df["Reported Year"] == 2019]["Reported Month"].value_counts()
# Out:
# Jan    57
# Feb    51
# Mar    35
# Name: Reported Month, dtype: int64

# %%
df.groupby(["Reported Year","Reported Month"]).count()["Web ID"][2019]
# Out:
# Reported Month
# Feb    51
# Jan    57
# Mar    35
# Name: Web ID, dtype: int64

# %% [markdown]
# ##### 6.	What are the top migration routes

# %%
df["Migration Route"].value_counts()[:5]
# Out:
# Central America to US    1507
# Central Mediterranean     499
# Western Mediterranean     255
# Eastern Mediterranean     230
# Western Balkans            64
# Name: Migration Route, dtype: int64

# %% [markdown]
# ##### 7.	List number of cases reported yearwise and compare them¶

# %%
df["Reported Year"].value_counts()
# Out:
# 2018    1506
# 2017    1356
# 2016    1275
# 2015     808
# 2014     245
# 2019     143
# Name: Reported Year, dtype: int64

# %%
df.groupby(["Reported Year","Reported Month"]).count()["Web ID"][2019]
# Out:
# Reported Month
# Feb    51
# Jan    57
# Mar    35
# Name: Web ID, dtype: int64

# %%
df.groupby(["Reported Year","Reported Month"]).count()["Web ID"][2014]
# Out:
# Reported Month
# Apr    19
# Aug    27
# Dec    15
# Feb    14
# Jan    16
# Jul    33
# Jun    31
# Mar    19
# May    22
# Nov     7
# Oct    19
# Sep    23
# Name: Web ID, dtype: int64

# %%
df.groupby(["Reported Year","Reported Month"]).count()["Web ID"][2017]
# Out:
# Reported Month
# Apr     61
# Aug    114
# Dec    136
# Feb     93
# Jan    129
# Jul    101
# Jun    148
# Mar     60
# May    108
# Nov    129
# Oct    127
# Sep    150
# Name: Web ID, dtype: int64

# %%
df.groupby(["Reported Year","Reported Month"]).count()["Web ID"][2018]
# Out:
# Reported Month
# Apr    126
# Aug    143
# Dec     58
# Feb    120
# Jan    117
# Jul    157
# Jun    176
# Mar    123
# May    131
# Nov     82
# Oct    134
# Sep    139
# Name: Web ID, dtype: int64

# %%
# !pip install folium

# %%
temp = df.copy()

# %%
import folium
try:
    location = temp["Location Coordinates"].str.split(",")
    map_ = folium.Map(location=[38.362368696592, 26.172509473654])
    for point in range(0, len(location)):
        folium.Marker(location[point], popup=temp["Region of Incident"][point]).add_to(map_)
    map_.save("map_.html")
except:
    pass
